# %%
# Nguyễn Việt Quang B22DCCN650
from keras.preprocessing.text import Tokenizer

texts = ["Tôi yêu học máy", "Học máy rất thú vị"]

tokenizer = Tokenizer(num_words=100)  # Chỉ giữ 100 từ phổ biến nhất
tokenizer.fit_on_texts(texts)

print(tokenizer.word_index)
# Output có thể là: {'học': 1, 'máy': 2, 'tôi': 3, 'yêu': 4, 'rất': 5, 'thú': 6, 'vị': 7}

sequences = tokenizer.texts_to_sequences(texts)
print(sequences)
# Output: [[3, 4, 1, 2], [1, 2, 5, 6, 7]]

# Nguyễn Việt Quang B22DCCN650
from keras.preprocessing.sequence import pad_sequences

padded_sequences = pad_sequences(sequences, maxlen=6, padding='post')
print(padded_sequences)
# Output:
# [[3 4 1 2 0 0]
#  [1 2 5 6 7 0]]

# Nguyễn Việt Quang B22DCCN650
from keras.models import Sequential
from keras.layers import Embedding, Flatten, Dense

model = Sequential()
model.add(Embedding(input_dim=100, output_dim=8, input_length=6))

# Nguyễn Việt Quang B22DCCN650
from keras.layers import LSTM

model = Sequential()
model.add(Embedding(input_dim=100, output_dim=8, input_length=6))
model.add(LSTM(16))  # LSTM với 16 units
model.add(Dense(1, activation='sigmoid'))  # Phân loại nhị phân

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Nguyễn Việt Quang B22DCCN650
from keras.applications import VGG16
from keras.models import Sequential
from keras.layers import Dense, Flatten

# Load mô hình VGG16 pretrained trên ImageNet, bỏ lớp fully connected cuối
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224,224,3))

model = Sequential()
model.add(base_model)  # Dùng mô hình pretrained làm feature extractor
model.add(Flatten())
model.add(Dense(10, activation='softmax'))  # Phân loại 10 loại hoa

# Nguyễn Viet Quang B22DCCN650
from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint(
    'best_model.h5',     # file lưu mô hình
    monitor='val_accuracy',  # giám sát accuracy trên validation
    save_best_only=True,     # chỉ lưu khi model tốt hơn trước
    mode='max'
)

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, callbacks=[checkpoint])

# Nguyễn Việt Quang B22DCCN650
from keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_loss',  # giám sát loss trên validation
    patience=5,          # số epoch không cải thiện trước khi dừng
    restore_best_weights=True  # phục hồi weights tốt nhất
)

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, callbacks=[early_stop])
